# %% [markdown]
# # Importing Libraries and Modules

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
IMAGE_SIZE = (256,256)
BATCH_SIZE = 32

# %% [markdown]
# # Importing Images

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/corn-or-maize-leaf-disease-dataset/data",
    shuffle=True,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 4188 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
len(dataset)
# Out:
# 131

# %%
plt.figure(figsize=(10,10))
for image_batch , label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis('off')

# %% [markdown]
# # Train-test Split

# %%
def get_dataset(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=8)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size) 
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_dataset(dataset)

# %%
print("Length of Training Dataset is",len(train_ds))
print("\nLength of Validation Dataset is",len(val_ds))
print("\nLength of Testing Dataset is",len(test_ds))
# Out:
# Length of Training Dataset is 104
#
# Length of Validation Dataset is 13
#
# Length of Testing Dataset is 14

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
layers.experimental.preprocessing.Resizing(256,256),
layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# # Model Building

# %%
n_classes = 4
input_shape = (BATCH_SIZE,256,256,3)
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32,(3,3),activation ='relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size = (3,3),activation ='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax'),
    
])
model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (32, 62, 62, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (32, 30, 30, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPoolin  (32, 14, 14, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPoolin  (32, 6, 6, 64)            0
#  g2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPoolin  (32, 2, 2, 64)            0
#  g2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 4)                   260
#
# =================================================================
# Total params: 183812 (718.02 KB)
# Trainable params: 183812 (718.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
metrics=['accuracy']
)

# %% [markdown]
# # Model Fitting

# %%
history = model.fit(
train_ds,
epochs=30,
batch_size=BATCH_SIZE,
verbose=1,
validation_data=val_ds)
# Out:
# Epoch 1/30
# 104/104 [==============================] - 41s 135ms/step - loss: 1.0004 - accuracy: 0.5193 - val_loss: 0.7533 - val_accuracy: 0.6202
# Epoch 2/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.5824 - accuracy: 0.7696 - val_loss: 0.5829 - val_accuracy: 0.7692
# Epoch 3/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.4607 - accuracy: 0.8198 - val_loss: 0.5979 - val_accuracy: 0.8510
# Epoch 4/30
# 104/104 [==============================] - 5s 53ms/step - loss: 0.3920 - accuracy: 0.8490 - val_loss: 0.3067 - val_accuracy: 0.8558
# Epoch 5/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.3538 - accuracy: 0.8538 - val_loss: 0.2727 - val_accuracy: 0.8870
# Epoch 6/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.3188 - accuracy: 0.8709 - val_loss: 0.2710 - val_accuracy: 0.8894
# Epoch 7/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.2960 - accuracy: 0.8836 - val_loss: 0.2533 - val_accuracy: 0.9062
# Epoch 8/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.2640 - accuracy: 0.8917 - val_loss: 0.3123 - val_accuracy: 0.8462
# Epoch 9/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.2513 - accuracy: 0.8986 - val_loss: 0.2437 - val_accuracy: 0.8966
# Epoch 10/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.2555 - accuracy: 0.9016 - val_loss: 0.2274 - val_accuracy: 0.8990
# Epoch 11/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.2317 - accuracy: 0.9019 - val_loss: 0.2151 - val_accuracy: 0.9014
# Epoch 12/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.2189 - accuracy: 0.9100 - val_loss: 0.1932 - val_accuracy: 0.9062
# Epoch 13/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.2001 - accuracy: 0.9194 - val_loss: 0.1809 - val_accuracy: 0.9279
# Epoch 14/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1946 - accuracy: 0.9221 - val_loss: 0.2038 - val_accuracy: 0.9135
# Epoch 15/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1873 - accuracy: 0.9257 - val_loss: 0.1597 - val_accuracy: 0.9303
# Epoch 16/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1523 - accuracy: 0.9374 - val_loss: 0.1482 - val_accuracy: 0.9231
# Epoch 17/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1537 - accuracy: 0.9419 - val_loss: 0.1396 - val_accuracy: 0.9423
# Epoch 18/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1471 - accuracy: 0.9437 - val_loss: 0.1389 - val_accuracy: 0.9471
# Epoch 19/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1256 - accuracy: 0.9513 - val_loss: 0.1367 - val_accuracy: 0.9495
# Epoch 20/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1021 - accuracy: 0.9621 - val_loss: 0.1440 - val_accuracy: 0.9519
# Epoch 21/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1829 - accuracy: 0.9404 - val_loss: 0.2313 - val_accuracy: 0.9207
# Epoch 22/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.1161 - accuracy: 0.9561 - val_loss: 0.1164 - val_accuracy: 0.9663
# Epoch 23/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.0753 - accuracy: 0.9723 - val_loss: 0.1281 - val_accuracy: 0.9567
# Epoch 24/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0629 - accuracy: 0.9786 - val_loss: 0.1163 - val_accuracy: 0.9688
# Epoch 25/30
# 104/104 [==============================] - 6s 53ms/step - loss: 0.0479 - accuracy: 0.9823 - val_loss: 0.0912 - val_accuracy: 0.9808
# Epoch 26/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0415 - accuracy: 0.9883 - val_loss: 0.0965 - val_accuracy: 0.9760
# Epoch 27/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.1226 - accuracy: 0.9630 - val_loss: 0.1436 - val_accuracy: 0.9591
# Epoch 28/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 0.1248 - val_accuracy: 0.9712
# Epoch 29/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0412 - accuracy: 0.9868 - val_loss: 0.0885 - val_accuracy: 0.9663
# Epoch 30/30
# 104/104 [==============================] - 6s 54ms/step - loss: 0.0420 - accuracy: 0.9859 - val_loss: 0.1261 - val_accuracy: 0.9639

# %%
scores = model.evaluate(test_ds)
# Out:
# 14/14 [==============================] - 7s 24ms/step - loss: 0.1073 - accuracy: 0.9710

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
his_data = pd.DataFrame(history.history)
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.plot(his_data.loss, label="Training loss")
plt.plot(his_data.val_loss, label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.title("Losses")
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(his_data.accuracy, label="Training accuracy")
plt.plot(his_data.val_accuracy, label="Validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy")
plt.grid()
plt.legend()

# %% [markdown]
# # Prediction

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("First Image to Predict :")
    plt.imshow(first_image)
    print("\nActual label:",class_names[first_label])
    batch_prediction = model.predict(images_batch) 
    print("\nPredicted label" ,class_names[np.argmax(batch_prediction[0])])
# Out:
# First Image to Predict :
#
# Actual label: Common_Rust
# 1/1 [==============================] - 0s 155ms/step
#
# Predicted label Common_Rust

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    predictions = model.predict (img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
#     confidence = round(np.max(predictions[0]),2)
    confidence = round(100*(np.max(predictions[0])),2)

    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class , confidence = predict(model,images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confidence Score: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
# model_version = 1
model.save('/kaggle/working/Disease_Classifier_Corn')
